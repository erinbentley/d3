# %% [markdown]
# ### WeatherPy

# %% [markdown]
# Data Viz Boot Camp | Python-API Homework
#
# Due Tuesday, January 7, 2020

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    #print(lat_lngs)
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #print(city)
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
#
# Perform a weather check on each city using a series of successive API calls.

# %%
appid = api_key
base_url = "api.openweathermap.org/data/2.5/weather?"+"&appid="+api_key
record = 1
set_num = 1
cityinfo = []

print("Beginning Data Retrieval")
print("-----------------------------")

for cityname in cities:
    #print(cityname)
    #base_url = "http://api.openweathermap.org/data/2.5/weather?"+"&appid="+api_key+"&q="+cityname
    #print(base_url)

    if record >50:
        record = 1
        set_num = set_num+1
# Include a print log of each city as it'sbeing processed (with the city number and city name).
    base_url = "http://api.openweathermap.org/data/2.5/weather?"+"&appid="+api_key+"&q="+cityname  
    weather_response = requests.get(base_url)
    weather_json = weather_response.json()
    #print (weather_response)
    print("Processing Record "+str(record)+ " of Set " + str(set_num) + " | " +str(cityname))
    record = record+1
    #print(weather_json)
    if weather_json["cod"]== 200:
        cityinfo.append(weather_json)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gurgan
# Processing Record 2 of Set 1 | kalmunai
# Processing Record 3 of Set 1 | madison
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | correntina
# Processing Record 7 of Set 1 | zabrat
# Processing Record 8 of Set 1 | liverpool
# Processing Record 9 of Set 1 | zhitikara
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | pelotas
# Processing Record 15 of Set 1 | kailua
# Processing Record 16 of Set 1 | westport
# Processing Record 17 of Set 1 | padang
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | mys shmidta
# Processing Record 21 of Set 1 | bam
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | xinyang
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | richards bay
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | tabou
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | ilulissat
# Processing Record 36 of Set 1 | luganville
# Processing Record 37 of Set 1 | salalah
# Processing Record 38 of Set 1 | verkhoyansk
# Processing Record 39 of Set 1 | tatawin
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | haines junction
# Processing Record 43 of Set 1 | hithadhoo
# Processing Record 44 of Set 1 | castro
# Processing Record 45 of Set 1 | sao domingos
# Processing Record 46 of Set 1 | martinez
# Processing Record 47 of Set 1 | nelson bay
# Processing Record 48 of Set 1 | bridlington
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | santa
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | roma
# Processing Record 4 of Set 2 | northam
# Processing Record 5 of Set 2 | naze
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | anadyr
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | amderma
# Processing Record 11 of Set 2 | gunjur
# Processing Record 12 of Set 2 | grand-santi
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | glarus
# Processing Record 15 of Set 2 | broken hill
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | komsomolskiy
# Processing Record 18 of Set 2 | kuji
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | kruisfontein
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | leningradskiy
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | mukhen
# Processing Record 25 of Set 2 | lata
# Processing Record 26 of Set 2 | grand river south east
# Processing Record 27 of Set 2 | strathmore
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | barcelos
# Processing Record 30 of Set 2 | barentsburg
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | kijang
# Processing Record 33 of Set 2 | awbari
# Processing Record 34 of Set 2 | vicente guerrero
# Processing Record 35 of Set 2 | gushikawa
# Processing Record 36 of Set 2 | eydhafushi
# Processing Record 37 of Set 2 | goundam
# Processing Record 38 of Set 2 | newport
# Processing Record 39 of Set 2 | bathsheba
# Processing Record 40 of Set 2 | san francisco
# Processing Record 41 of Set 2 | barawe
# Processing Record 42 of Set 2 | plettenberg bay
# Processing Record 43 of Set 2 | saint anthony
# Processing Record 44 of Set 2 | maniitsoq
# Processing Record 45 of Set 2 | hihifo
# Processing Record 46 of Set 2 | tobermory
# Processing Record 47 of Set 2 | fougamou
# Processing Record 48 of Set 2 | sitka
# Processing Record 49 of Set 2 | buchanan
# Processing Record 50 of Set 2 | erenhot
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | dunedin
# Processing Record 4 of Set 3 | samusu
# Processing Record 5 of Set 3 | taolanaro
# Processing Record 6 of Set 3 | minden
# Processing Record 7 of Set 3 | suntar
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | coahuayana
# Processing Record 11 of Set 3 | orlik
# Processing Record 12 of Set 3 | saskylakh
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | katsuura
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | kavieng
# Processing Record 17 of Set 3 | hobart
# Processing Record 18 of Set 3 | svetlogorsk
# Processing Record 19 of Set 3 | belushya guba
# Processing Record 20 of Set 3 | yenagoa
# Processing Record 21 of Set 3 | barrow
# Processing Record 22 of Set 3 | mugumu
# Processing Record 23 of Set 3 | thouars
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | lauro muller
# Processing Record 27 of Set 3 | carutapera
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | halifax
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | sturgis
# Processing Record 32 of Set 3 | mahebourg
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | neuquen
# Processing Record 35 of Set 3 | mitha tiwana
# Processing Record 36 of Set 3 | soyo
# Processing Record 37 of Set 3 | koani
# Processing Record 38 of Set 3 | havoysund
# Processing Record 39 of Set 3 | fairbanks
# Processing Record 40 of Set 3 | mandalgovi
# Processing Record 41 of Set 3 | tsihombe
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | formoso do araguaia
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | kavaratti
# Processing Record 46 of Set 3 | uray
# Processing Record 47 of Set 3 | bakchar
# Processing Record 48 of Set 3 | catio
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | maneadero
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | pingzhuang
# Processing Record 3 of Set 4 | ribeira grande
# Processing Record 4 of Set 4 | vao
# Processing Record 5 of Set 4 | meiktila
# Processing Record 6 of Set 4 | cape town
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | ayr
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | springbok
# Processing Record 11 of Set 4 | laparay
# Processing Record 12 of Set 4 | saint-pierre
# Processing Record 13 of Set 4 | wanaka
# Processing Record 14 of Set 4 | vila
# Processing Record 15 of Set 4 | dingle
# Processing Record 16 of Set 4 | culasi
# Processing Record 17 of Set 4 | khani
# Processing Record 18 of Set 4 | aswan
# Processing Record 19 of Set 4 | kalmar
# Processing Record 20 of Set 4 | camacha
# Processing Record 21 of Set 4 | college
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | ayagoz
# Processing Record 24 of Set 4 | hangu
# Processing Record 25 of Set 4 | taoudenni
# Processing Record 26 of Set 4 | yulara
# Processing Record 27 of Set 4 | ngunguru
# Processing Record 28 of Set 4 | sioux lookout
# Processing Record 29 of Set 4 | mount vernon
# Processing Record 30 of Set 4 | kununurra
# Processing Record 31 of Set 4 | nouadhibou
# Processing Record 32 of Set 4 | illoqqortoormiut
# Processing Record 33 of Set 4 | coihaique
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | iisalmi
# Processing Record 36 of Set 4 | vanimo
# Processing Record 37 of Set 4 | the valley
# Processing Record 38 of Set 4 | hamilton
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | axim
# Processing Record 41 of Set 4 | atagay
# Processing Record 42 of Set 4 | santa isabel do rio negro
# Processing Record 43 of Set 4 | hualmay
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | bud
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | carnarvon
# Processing Record 48 of Set 4 | nizhnevartovsk
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | sentyabrskiy
# Processing Record 1 of Set 5 | novyy urgal
# Processing Record 2 of Set 5 | bogorodskoye
# Processing Record 3 of Set 5 | santa rosa
# Processing Record 4 of Set 5 | thanh hoa
# Processing Record 5 of Set 5 | zhanaozen
# Processing Record 6 of Set 5 | flin flon
# Processing Record 7 of Set 5 | tumannyy
# Processing Record 8 of Set 5 | yerbogachen
# Processing Record 9 of Set 5 | hobyo
# Processing Record 10 of Set 5 | tucurui
# Processing Record 11 of Set 5 | bondo
# Processing Record 12 of Set 5 | saint-louis
# Processing Record 13 of Set 5 | necochea
# Processing Record 14 of Set 5 | qaqortoq
# Processing Record 15 of Set 5 | tuim
# Processing Record 16 of Set 5 | kloulklubed
# Processing Record 17 of Set 5 | coquimbo
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | fortuna
# Processing Record 20 of Set 5 | pevek
# Processing Record 21 of Set 5 | sibu
# Processing Record 22 of Set 5 | slave lake
# Processing Record 23 of Set 5 | chimbote
# Processing Record 24 of Set 5 | kirakira
# Processing Record 25 of Set 5 | ambovombe
# Processing Record 26 of Set 5 | cayenne
# Processing Record 27 of Set 5 | khatanga
# Processing Record 28 of Set 5 | cascas
# Processing Record 29 of Set 5 | nhulunbuy
# Processing Record 30 of Set 5 | koch bihar
# Processing Record 31 of Set 5 | kangaatsiaq
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | kholm
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | clyde river
# Processing Record 36 of Set 5 | amapa
# Processing Record 37 of Set 5 | presidencia roque saenz pena
# Processing Record 38 of Set 5 | tuy hoa
# Processing Record 39 of Set 5 | pudozh
# Processing Record 40 of Set 5 | bethel
# Processing Record 41 of Set 5 | srednekolymsk
# Processing Record 42 of Set 5 | teluk nibung
# Processing Record 43 of Set 5 | karratha
# Processing Record 44 of Set 5 | kralendijk
# Processing Record 45 of Set 5 | najran
# Processing Record 46 of Set 5 | attawapiskat
# Processing Record 47 of Set 5 | asosa
# Processing Record 48 of Set 5 | isangel
# Processing Record 49 of Set 5 | saleaula
# Processing Record 50 of Set 5 | pinega
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | ourem
# Processing Record 3 of Set 6 | mangan
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | zhob
# Processing Record 6 of Set 6 | katherine
# Processing Record 7 of Set 6 | puerto baquerizo moreno
# Processing Record 8 of Set 6 | sterling
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | erzin
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | crotone
# Processing Record 14 of Set 6 | paita
# Processing Record 15 of Set 6 | margate
# Processing Record 16 of Set 6 | garowe
# Processing Record 17 of Set 6 | olenino
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | aleksandrov gay
# Processing Record 20 of Set 6 | blonduos
# Processing Record 21 of Set 6 | avera
# Processing Record 22 of Set 6 | nome
# Processing Record 23 of Set 6 | dudinka
# Processing Record 24 of Set 6 | talcahuano
# Processing Record 25 of Set 6 | kannur
# Processing Record 26 of Set 6 | ajdabiya
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | celestun
# Processing Record 29 of Set 6 | namibe
# Processing Record 30 of Set 6 | tilichiki
# Processing Record 31 of Set 6 | san julian
# Processing Record 32 of Set 6 | cidreira
# Processing Record 33 of Set 6 | ranong
# Processing Record 34 of Set 6 | ostersund
# Processing Record 35 of Set 6 | arzgir
# Processing Record 36 of Set 6 | sainte-rose
# Processing Record 37 of Set 6 | mitsamiouli
# Processing Record 38 of Set 6 | tura
# Processing Record 39 of Set 6 | lasa
# Processing Record 40 of Set 6 | karaton
# Processing Record 41 of Set 6 | faya
# Processing Record 42 of Set 6 | cairns
# Processing Record 43 of Set 6 | ketchikan
# Processing Record 44 of Set 6 | umm durman
# Processing Record 45 of Set 6 | ogulin
# Processing Record 46 of Set 6 | omboue
# Processing Record 47 of Set 6 | upernavik
# Processing Record 48 of Set 6 | anzio
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | pyu
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | port hardy
# Processing Record 3 of Set 7 | paamiut
# Processing Record 4 of Set 7 | beloha
# Processing Record 5 of Set 7 | hambantota
# Processing Record 6 of Set 7 | buin
# Processing Record 7 of Set 7 | wau
# Processing Record 8 of Set 7 | payo
# Processing Record 9 of Set 7 | tambopata
# Processing Record 10 of Set 7 | tiznit
# Processing Record 11 of Set 7 | yumen
# Processing Record 12 of Set 7 | aykhal
# Processing Record 13 of Set 7 | la libertad
# Processing Record 14 of Set 7 | jacareacanga
# Processing Record 15 of Set 7 | punta alta
# Processing Record 16 of Set 7 | tambul
# Processing Record 17 of Set 7 | henties bay
# Processing Record 18 of Set 7 | felidhoo
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | smoky lake
# Processing Record 21 of Set 7 | umzimvubu
# Processing Record 22 of Set 7 | reconquista
# Processing Record 23 of Set 7 | bunia
# Processing Record 24 of Set 7 | rocky mountain house
# Processing Record 25 of Set 7 | tagusao
# Processing Record 26 of Set 7 | timbiqui
# Processing Record 27 of Set 7 | jumla
# Processing Record 28 of Set 7 | jardim
# Processing Record 29 of Set 7 | klaksvik
# Processing Record 30 of Set 7 | strood
# Processing Record 31 of Set 7 | pafos
# Processing Record 32 of Set 7 | xifeng
# Processing Record 33 of Set 7 | sungai padi
# Processing Record 34 of Set 7 | jiexiu
# Processing Record 35 of Set 7 | soron
# Processing Record 36 of Set 7 | bonavista
# Processing Record 37 of Set 7 | gat
# Processing Record 38 of Set 7 | kamina
# Processing Record 39 of Set 7 | vaitupu
# Processing Record 40 of Set 7 | esperance
# Processing Record 41 of Set 7 | shellbrook
# Processing Record 42 of Set 7 | key west
# Processing Record 43 of Set 7 | madimba
# Processing Record 44 of Set 7 | hyderabad
# Processing Record 45 of Set 7 | turukhansk
# Processing Record 46 of Set 7 | tokur
# Processing Record 47 of Set 7 | pineville
# Processing Record 48 of Set 7 | aranos
# Processing Record 49 of Set 7 | ichalkaranji
# Processing Record 50 of Set 7 | half moon bay
# Processing Record 1 of Set 8 | ciurila
# Processing Record 2 of Set 8 | longyearbyen
# Processing Record 3 of Set 8 | moultrie
# Processing Record 4 of Set 8 | upata
# Processing Record 5 of Set 8 | barth
# Processing Record 6 of Set 8 | chuy
# Processing Record 7 of Set 8 | forbes
# Processing Record 8 of Set 8 | antalaha
# Processing Record 9 of Set 8 | trinidad
# Processing Record 10 of Set 8 | warqla
# Processing Record 11 of Set 8 | orel-izumrud
# Processing Record 12 of Set 8 | ancud
# Processing Record 13 of Set 8 | puerto el triunfo
# Processing Record 14 of Set 8 | hami
# Processing Record 15 of Set 8 | mecca
# Processing Record 16 of Set 8 | bonthe
# Processing Record 17 of Set 8 | rovinj
# Processing Record 18 of Set 8 | pirapemas
# Processing Record 19 of Set 8 | kazalinsk
# Processing Record 20 of Set 8 | holme
# Processing Record 21 of Set 8 | kamenskoye
# Processing Record 22 of Set 8 | orange cove
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | isla vista
# Processing Record 26 of Set 8 | lompoc
# Processing Record 27 of Set 8 | slavutych
# Processing Record 28 of Set 8 | brae
# Processing Record 29 of Set 8 | lebedinyy
# Processing Record 30 of Set 8 | maningrida
# Processing Record 31 of Set 8 | kieta
# Processing Record 32 of Set 8 | nikel
# Processing Record 33 of Set 8 | anloga
# Processing Record 34 of Set 8 | husavik
# Processing Record 35 of Set 8 | sibolga
# Processing Record 36 of Set 8 | caravelas
# Processing Record 37 of Set 8 | chenzhou
# Processing Record 38 of Set 8 | bilma
# Processing Record 39 of Set 8 | aklavik
# Processing Record 40 of Set 8 | ust-maya
# Processing Record 41 of Set 8 | bisira
# Processing Record 42 of Set 8 | grand gaube
# Processing Record 43 of Set 8 | conneaut
# Processing Record 44 of Set 8 | wanning
# Processing Record 45 of Set 8 | broome
# Processing Record 46 of Set 8 | kendari
# Processing Record 47 of Set 8 | marataizes
# Processing Record 48 of Set 8 | marienburg
# Processing Record 49 of Set 8 | varkaus
# Processing Record 50 of Set 8 | karkaralinsk
# Processing Record 1 of Set 9 | banda aceh
# Processing Record 2 of Set 9 | kholodnyy
# Processing Record 3 of Set 9 | chernyshevskiy
# Processing Record 4 of Set 9 | panikian
# Processing Record 5 of Set 9 | tiarei
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | dabola
# Processing Record 8 of Set 9 | gamboula
# Processing Record 9 of Set 9 | jiuquan
# Processing Record 10 of Set 9 | sistranda
# Processing Record 11 of Set 9 | comodoro rivadavia
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | kingman
# Processing Record 14 of Set 9 | toccoa
# Processing Record 15 of Set 9 | chokwe
# Processing Record 16 of Set 9 | general roca
# Processing Record 17 of Set 9 | te anau
# Processing Record 18 of Set 9 | quatre cocos
# Processing Record 19 of Set 9 | ariquemes
# Processing Record 20 of Set 9 | tuatapere
# Processing Record 21 of Set 9 | ternate
# Processing Record 22 of Set 9 | svetlyy
# Processing Record 23 of Set 9 | ostrovnoy
# Processing Record 24 of Set 9 | kuna
# Processing Record 25 of Set 9 | hunza
# Processing Record 26 of Set 9 | lucapa
# Processing Record 27 of Set 9 | zolotinka
# Processing Record 28 of Set 9 | great yarmouth
# Processing Record 29 of Set 9 | rantepao
# Processing Record 30 of Set 9 | beyneu
# Processing Record 31 of Set 9 | lagoa
# Processing Record 32 of Set 9 | terrace
# Processing Record 33 of Set 9 | bezhetsk
# Processing Record 34 of Set 9 | inirida
# Processing Record 35 of Set 9 | atar
# Processing Record 36 of Set 9 | marsh harbour
# Processing Record 37 of Set 9 | san antonio
# Processing Record 38 of Set 9 | sulzbach-rosenberg
# Processing Record 39 of Set 9 | vilyuysk
# Processing Record 40 of Set 9 | san cristobal
# Processing Record 41 of Set 9 | isla mujeres
# Processing Record 42 of Set 9 | mundo novo
# Processing Record 43 of Set 9 | luau
# Processing Record 44 of Set 9 | donaueschingen
# Processing Record 45 of Set 9 | tingi
# Processing Record 46 of Set 9 | paradwip
# Processing Record 47 of Set 9 | kati
# Processing Record 48 of Set 9 | alta floresta
# Processing Record 49 of Set 9 | sept-iles
# Processing Record 50 of Set 9 | bull savanna
# Processing Record 1 of Set 10 | naryan-mar
# Processing Record 2 of Set 10 | tual
# Processing Record 3 of Set 10 | vila velha
# Processing Record 4 of Set 10 | lazaro cardenas
# Processing Record 5 of Set 10 | kamaishi
# Processing Record 6 of Set 10 | takayama
# Processing Record 7 of Set 10 | namatanai
# Processing Record 8 of Set 10 | lakatoro
# Processing Record 9 of Set 10 | belur
# Processing Record 10 of Set 10 | la sarre
# Processing Record 11 of Set 10 | eston
# Processing Record 12 of Set 10 | colares
# Processing Record 13 of Set 10 | sataua
# Processing Record 14 of Set 10 | shambu
# Processing Record 15 of Set 10 | mondlo
# Processing Record 16 of Set 10 | kericho
# Processing Record 17 of Set 10 | eureka
# Processing Record 18 of Set 10 | viedma
# Processing Record 19 of Set 10 | pacific grove
# Processing Record 20 of Set 10 | yinchuan
# Processing Record 21 of Set 10 | falakata
# Processing Record 22 of Set 10 | lorengau
# Processing Record 23 of Set 10 | hasaki
# Processing Record 24 of Set 10 | saint-augustin
# Processing Record 25 of Set 10 | sambava
# Processing Record 26 of Set 10 | abaza
# Processing Record 27 of Set 10 | votkinsk
# Processing Record 28 of Set 10 | guozhen
# Processing Record 29 of Set 10 | mana
# Processing Record 30 of Set 10 | leh
# Processing Record 31 of Set 10 | umm lajj
# Processing Record 32 of Set 10 | ramnagar
# Processing Record 33 of Set 10 | puerto montt
# Processing Record 34 of Set 10 | zachagansk
# Processing Record 35 of Set 10 | aripuana
# Processing Record 36 of Set 10 | aksarka
# Processing Record 37 of Set 10 | norman wells
# Processing Record 38 of Set 10 | utiroa
# Processing Record 39 of Set 10 | savelugu
# Processing Record 40 of Set 10 | dum duma
# Processing Record 41 of Set 10 | finschhafen
# Processing Record 42 of Set 10 | grindavik
# Processing Record 43 of Set 10 | ciudad guayana
# Processing Record 44 of Set 10 | khujand
# Processing Record 45 of Set 10 | hirara
# Processing Record 46 of Set 10 | rognan
# Processing Record 47 of Set 10 | ishigaki
# Processing Record 48 of Set 10 | marawi
# Processing Record 49 of Set 10 | aginskoye
# Processing Record 50 of Set 10 | cajamarca
# Processing Record 1 of Set 11 | nguiu
# Processing Record 2 of Set 11 | baker city
# Processing Record 3 of Set 11 | suez
# Processing Record 4 of Set 11 | bagula
# Processing Record 5 of Set 11 | arvika
# Processing Record 6 of Set 11 | itarema
# Processing Record 7 of Set 11 | korcula
# Processing Record 8 of Set 11 | los llanos de aridane
# Processing Record 9 of Set 11 | oranjemund
# Processing Record 10 of Set 11 | wanxian
# Processing Record 11 of Set 11 | agirish
# Processing Record 12 of Set 11 | airai
# Processing Record 13 of Set 11 | belyy yar
# Processing Record 14 of Set 11 | mundo nuevo
# Processing Record 15 of Set 11 | parrita
# Processing Record 16 of Set 11 | saint-georges
# Processing Record 17 of Set 11 | anar darreh
# Processing Record 18 of Set 11 | faro
# Processing Record 19 of Set 11 | luena
# Processing Record 20 of Set 11 | sao joao da barra
# Processing Record 21 of Set 11 | chifeng
# Processing Record 22 of Set 11 | baiyin
# Processing Record 23 of Set 11 | laiagam
# Processing Record 24 of Set 11 | labuhan
# Processing Record 25 of Set 11 | puerto penasco
# Processing Record 26 of Set 11 | butte
# Processing Record 27 of Set 11 | santa maria
# Processing Record 28 of Set 11 | lima
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | lithakia
# Processing Record 31 of Set 11 | san carlos del zulia
# Processing Record 32 of Set 11 | dawson creek
# Processing Record 33 of Set 11 | nianzishan
# Processing Record 34 of Set 11 | laguna
# Processing Record 35 of Set 11 | whitianga
# Processing Record 36 of Set 11 | cockburn town
# Processing Record 37 of Set 11 | ous
# Processing Record 38 of Set 11 | mugur-aksy
# Processing Record 39 of Set 11 | poya
# Processing Record 40 of Set 11 | piacabucu
# Processing Record 41 of Set 11 | baragaon
# Processing Record 42 of Set 11 | qinzhou
# Processing Record 43 of Set 11 | wenling
# Processing Record 44 of Set 11 | pathein
# Processing Record 45 of Set 11 | peniche
# Processing Record 46 of Set 11 | mbandaka
# Processing Record 47 of Set 11 | banjarmasin
# Processing Record 48 of Set 11 | rancharia
# Processing Record 49 of Set 11 | sao jose da coroa grande
# Processing Record 50 of Set 11 | babanusah
# Processing Record 1 of Set 12 | dabakala
# Processing Record 2 of Set 12 | vuktyl
# Processing Record 3 of Set 12 | cootamundra
# Processing Record 4 of Set 12 | semnan
# Processing Record 5 of Set 12 | marcona
# Processing Record 6 of Set 12 | ruatoria
# Processing Record 7 of Set 12 | karamea
# Processing Record 8 of Set 12 | praia da vitoria
# Processing Record 9 of Set 12 | mul
# Processing Record 10 of Set 12 | tautira
# Processing Record 11 of Set 12 | merauke
# Processing Record 12 of Set 12 | astana
# Processing Record 13 of Set 12 | aljezur
# Processing Record 14 of Set 12 | dubti
# Processing Record 15 of Set 12 | luderitz
# Processing Record 16 of Set 12 | abucay
# Processing Record 17 of Set 12 | purranque
# Processing Record 18 of Set 12 | felanitx
# Processing Record 19 of Set 12 | dolbeau
# Processing Record 20 of Set 12 | olga
# Processing Record 21 of Set 12 | abeche
# Processing Record 22 of Set 12 | dubbo
# Processing Record 23 of Set 12 | pulaski
# Processing Record 24 of Set 12 | gberia fotombu
# Processing Record 25 of Set 12 | thaton
# Processing Record 26 of Set 12 | nynashamn
# Processing Record 27 of Set 12 | arinos
# Processing Record 28 of Set 12 | medea
# Processing Record 29 of Set 12 | isabela
# Processing Record 30 of Set 12 | cabedelo
# Processing Record 31 of Set 12 | lake saint louis
# Processing Record 32 of Set 12 | garissa
# Processing Record 33 of Set 12 | rosarito
# Processing Record 34 of Set 12 | owando
# Processing Record 35 of Set 12 | northampton
# Processing Record 36 of Set 12 | goure
# Processing Record 37 of Set 12 | khabary
# Processing Record 38 of Set 12 | daru
# Processing Record 39 of Set 12 | kandrian
# Processing Record 40 of Set 12 | danilovka
# Processing Record 41 of Set 12 | tweed
# Processing Record 42 of Set 12 | acapulco

# %% [markdown]
# ### Convert Raw Data to DataFrame
#
# Export the city data into a .csv.
# Display the DataFrame

# %%
#print(cityinfo)
citytable = []

for citydata in cityinfo:
    citytable.append({"City": citydata["name"],"Cloudiness": citydata["clouds"]["all"],
                      "Country": citydata["sys"]["country"],"Date": citydata["dt"],
                      "Humidity": citydata["main"]["humidity"],"Lat": citydata["coord"]["lat"],
                      "Lng": citydata["coord"]["lon"],"Max Temp": citydata["main"]["temp_max"],
                      "Wind Speed": citydata["wind"]["speed"]})
      
#city_df
#citytable

# %%
city_df = pd.DataFrame(citytable)
city_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0       Kalmunai          81      LK  1578367220        78   7.42  81.82
# 1        Madison          90      US  1578366860        69  43.07 -89.38
# 2  Mar del Plata          69      AR  1578367487        61 -46.43 -67.52
# 3     Georgetown          41      GY  1578367487        83   6.80 -58.16
# 4     Correntina         100      BR  1578367487        94 -13.34 -44.63
#
#    Max Temp  Wind Speed
# 0    301.09        7.60
# 1    275.15        2.10
# 2    289.86        1.43
# 3    297.15        2.10
# 4    294.35        1.61

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(10,8))
plt.scatter(city_df["Lat"],city_df["Max Temp"],color="purple")

plt.title("City Latitude vs. Max Temperature (8/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(axis = 'y')
plt.grid(axis = 'x')

# Save the Figure
plt.savefig("data/lat_vs_temp.png")
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,8))
plt.scatter(city_df["Lat"], city_df["Humidity"],color="purple")


plt.title("City Latitude vs. Humidity (8/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(axis = 'y')
plt.grid(axis = 'x')

# Save the Figure
plt.savefig("data/lat_vs_humidity.png")
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10,8))
plt.scatter(city_df["Lat"], city_df["Cloudiness"],color="purple")

plt.title("City Latitude vs. Cloudiness (8/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(axis = 'y')
plt.grid(axis = 'x')

# Save the Figure
plt.savefig("data/lat_vs_clouds.png")
# Show the Figure
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10,8))
plt.scatter(city_df["Lat"], city_df["Wind Speed"],color="purple")

plt.title("City Latitude vs. Wind Speed (8/22/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(axis = 'y')
plt.grid(axis = 'x')

# Save the Figure
plt.savefig("data/lat_vs_wind.png")
# Show the Figure
plt.show()
